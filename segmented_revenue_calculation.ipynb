# %%
import pandas as pd
import requests
from pprint import pprint
from math import ceil
import copy
import random
from datetime import datetime, timedelta

# %% [markdown]
# # Supporting Functions

# %%
def chunk_list(lst, chunk_size):
    """
    Splits a list into chunks of specified size.
    
    Parameters:
        lst (list): The list to split.
        chunk_size (int): The maximum size of each chunk.
        
    Returns:
        generator: A generator that yields chunks of the list.
    """
    for i in range(0, len(lst), chunk_size):
        yield lst[i:i + chunk_size]

# %%
def get_unified_app_data(api_key, base_url, app_ids):
    """
    Fetch unified app data from the SensorTower API in batches of 100 IDs per request.
    
    Parameters:
        api_key (str): Your SensorTower API key.
        base_url (str): The base URL for the API.
        app_ids (list[str]): List of unified app IDs to fetch.
        
    Returns:
        list[dict]: Combined response data from all requests.
    """
    
    # API endpoint
    endpoint = "/v1/unified/apps"
    url = f"{base_url}{endpoint}"
    
    headers = {
        'Authorization': f'Bearer {api_key}'
    }
    
    all_responses = []
    chunk_size = 100
    count = 1
    
    # Split the list of app_ids into chunks of 100
    for app_id_chunk in chunk_list(app_ids, chunk_size):
        params = {
            'app_id_type': 'unified',
            'app_ids': ','.join(app_id_chunk)
        }
        
        print('making call for chunk number {}'.format(count))
        
        # Make the API request for this chunk
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 200:
            print('call successful!')
            all_responses.extend(response.json().get('apps', []))
        else:
            print(f"Request failed with status code {response.status_code}: {response.text}")
        
        count += 1
    
    return all_responses

# %%
def extract_app_ids(list_of_dict):
    return list(map(lambda d: d['app_id'], list_of_dict))

# %%
def get_app_id_lists(unified_app_data):
#     also known as canonical data, cuz it also contains canonical id thingy
    itunes_app_id_list = []
    android_app_id_list = []
    
    for app in unified_app_data:
        current_app_itunes_app_ids = app['itunes_apps']
        current_app_android_app_ids = app['android_apps']
        itunes_app_id_list.extend(extract_app_ids(current_app_itunes_app_ids))
        android_app_id_list.extend(extract_app_ids(current_app_android_app_ids))
    
#     ios app id list needs to be adjusted (but not for android app id list)
    itunes_app_id_list_adjusted = list(map(lambda x: str(x),itunes_app_id_list))
    
    result_list = []
    
    for app_id in itunes_app_id_list_adjusted:
        result_list.append(
            {
                'os':'ios',
                'app_id':app_id
            }
        
        )

    for app_id in android_app_id_list:
        result_list.append(
            {
                'os':'android',
                'app_id':app_id
            }
        
        )
    
    return result_list

# %%
def get_local_app_info(api_key, base_url, os, app_ids):
    
    # API endpoint
    endpoint = "/v1/{}/apps".format(os)
    url = f"{base_url}{endpoint}"
    
    headers = {
        'Authorization': f'Bearer {api_key}'
    }
    
    all_responses = []
    chunk_size = 100
    count = 1
    
    # Split the list of app_ids into chunks of 100
    for app_id_chunk in chunk_list(app_ids, chunk_size):
        params = {
            'app_ids': ','.join(app_id_chunk)
        }
        
        print('making call for chunk number {}'.format(count))
        
        # Make the API request for this chunk
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 200:
            print('call successful!')
            all_responses.extend(response.json().get('apps', []))
        else:
            print(f"Request failed with status code {response.status_code}: {response.text}")
        
        count += 1
    
    return all_responses

# %%
def get_monthly_app_performance_single_app_id(api_key, base_url, os, app_id, country_code, start_date, end_date):
    """
    Query monthly app performance data in 12-month segments if the range exceeds 12 months.
    """
    
    def split_date_range(start_date, end_date, max_months=12):
        """
        Split a date range into non-overlapping segments of up to `max_months` months.
        """
        current_start = datetime.strptime(start_date, '%Y-%m-%d')
        final_end = datetime.strptime(end_date, '%Y-%m-%d')
        date_ranges = []

        while current_start < final_end:
            # Calculate the end date for the current range
            current_end = current_start + timedelta(days=max_months * 30)  # Approximate 12 months
            # Ensure current_end does not exceed final_end
            current_end = min(current_end, final_end)
            # Adjust current_end to the last day of the month
            current_end = (current_end.replace(day=1) + timedelta(days=32)).replace(day=1) - timedelta(days=1)

            # Add the range to the list
            date_ranges.append((current_start.strftime('%Y-%m-%d'), current_end.strftime('%Y-%m-%d')))

            # Move current_start to the first day of the next month after current_end
            current_start = (current_end + timedelta(days=1)).replace(day=1)

        return date_ranges
    
    print("Getting performance data for app id {}".format(app_id))

    endpoint = "/v1/{}/sales_report_estimates".format(os)
    url = f"{base_url}{endpoint}"

    headers = {
        'Authorization': f'Bearer {api_key}'
    }

    date_ranges = split_date_range(start_date, end_date)
    
#     print("Date Ranges")
#     print(date_ranges)
    
    
    all_results = []

    for start, end in date_ranges:
        params = {
            'os': os,
            'app_ids': app_id,
            'countries': country_code,
            'date_granularity': 'monthly',
            'start_date': start,
            'end_date': end,
        }

        request = requests.Request("GET", url, headers=headers, params=params)
        prepared_request = request.prepare()

#         print("Requesting Data for Range:", start, "to", end)
#         print("Full Request URL:", prepared_request.url)

        response = requests.get(url, headers=headers, params=params)

        if response.status_code == 200:
            print(f"Data retrieved for {start} to {end}")
            json_data = response.json()
            if isinstance(json_data, list):  # If the response is a list
                all_results.extend(json_data)
            elif isinstance(json_data, dict):  # If the response is a dictionary
                all_results.extend(json_data.get('data', []))
            else:
                print(f"Unexpected response format for {start} to {end}: {json_data}")
        else:
            print(f"Failed for {start} to {end}. Status Code: {response.status_code}")
            print(response.text)
    
    return all_results

# %%
def get_performance_streams_from_list_of_app_ids(api_key, base_url, country_code, start_date, end_date, list_app_ids):
    
    result = []
    
    for app in list_app_ids:
        os = app["os"]
        app_id = app["app_id"]
        app_performance = get_monthly_app_performance_single_app_id(
            api_key, 
            base_url, 
            os, 
            app_id, 
            country_code,
            start_date, 
            end_date
        )
        result.append(
            {
                'app_id': app_id,
                'os': os,
                'app_performance': app_performance
            }
        )

    return result

# %%
def get_unique_dates(performance_streams_data):
    result = []
    for app in performance_streams_data:
        for record in app['app_performance']:
            if not(record['d'] in result):
                result.append(record['d'])
    return sorted(result)

# %%
def get_app_ids_from_performance_stream_data(performance_stream_data):
    return list(map(lambda x: x['app_id'], performance_stream_data))

# %% [markdown]
# # API Credentials

# %%
api_key = 'ST0_ejEo8DwM_vCjQJzNhPbpmhQ'
base_url = 'https://api.sensortower.com'

# using authentication token from chi Tram's account

# %% [markdown]
# # Load st data file

# %%
# Load data
raw_game_data_df = pd.read_excel("data/output/st_game_data_2014_2024.xlsx")

# %%
raw_game_data_df
# Out:
#                                             Unified Name  \
# 0      Vermillion Watch: Moorgate Accord - Hidden Obj...
# 1                          SSC '22 - Super Soccer Champs
# 2                          Sphinx Trivia - Win Real Cash
# 3                                            Hero Realms
# 4                           Hexapolis: Civilization wars
# ...                                                  ...
# 97270                             Resimli Kelime Bulmaca
# 97271                                    Black Metal Man
# 97272                     Эврика! Логические Задачи Игры
# 97273                       Cotton Candy!  - Maker Games
# 97274                       GrassGames Cribbage for iPad
#
#                      Unified ID Unified Publisher Name  \
# 0      58cb5ba50211a68f8e00007e           Pixel United
# 1      5cf1572b49a1a977dbf7f9f8           CMA Megacorp
# 2      5b5e6a963d7e3c2daafcc304              GMRD Apps
# 3      629e1bd818009713fd2efc35      Wise Wizard Games
# 4      605587da4ebdbc721f470cb6          Jiri Bukovjan
# ...                         ...                    ...
# 97270  55d20e5b02ac64ee730006cb          Bretzel Games
# 97271  537b76ff830f782dbe00c0f9               SinSquid
# 97272  55d20e5702ac64ee730005ef       Nekhoroshev Ilya
# 97273  55d93a3b02ac645ad203e6ef  Bluebear Technologies
# 97274  559dcb7c942994f7e30006c6             GrassGames
#
#            Unified Publisher ID       Date Platform  Category  \
# 0      56289df502ac6486a7009de2 2024-01-01  Unified     Games
# 1      560c7c878ac350643902ef59 2024-01-01  Unified     Games
# 2      5ee985beaf4b673c0e63d3df 2024-01-01  Unified     Games
# 3      61e9b3ce6d8df53175fcc9ee 2024-01-01  Unified     Games
# 4      55f896028ac350426b044f4d 2024-01-01  Unified  Strategy
# ...                         ...        ...      ...       ...
# 97270  5cc750557927800edc53a6ce 2014-01-01  Unified      Word
# 97271  5604943f8ac350172200fddc 2014-01-01  Unified     Music
# 97272  55f893ad8ac350426b039896 2014-01-01  Unified    Trivia
# 97273  5614dc003f07e25d29019275 2014-01-01  Unified     Games
# 97274  55f8921f8ac350426b031929 2014-01-01  Unified      Card
#
#        Downloads (Absolute)  Downloads (Growth)  Downloads (Growth %)  \
# 0                         0                   0                   NaN
# 1                      2034               -1546                 -0.43
# 2                         7                   6                  6.00
# 3                         0                  -5                 -1.00
# 4                      4305               -5224                 -0.55
# ...                     ...                 ...                   ...
# 97270                   110                 110                   NaN
# 97271                     0                   0                   NaN
# 97272                     0                   0                   NaN
# 97273                  4295               -3928                 -0.48
# 97274                     0                   0                   NaN
#
#        Revenue (Absolute, $)  Revenue (Growth, $)  Revenue (Growth %)  \
# 0                      38.26                -7.90               -0.17
# 1                    1423.87             -1007.01               -0.41
# 2                    1416.69              -183.91               -0.11
# 3                    1418.47               854.43                1.51
# 4                    1418.83               593.34                0.72
# ...                      ...                  ...                 ...
# 97270                   3.95                 3.95                 NaN
# 97271                   3.94                 3.94                 NaN
# 97272                   3.93                 3.93                 NaN
# 97273                   3.93               -45.88               -0.92
# 97274                   0.31                 0.31                 NaN
#
#        Average DAU (Absolute)  Average DAU (Growth)  Average DAU (Growth %)
# 0                         NaN                   NaN                     NaN
# 1                        15.0                 -15.0                   -0.50
# 2                         NaN                   NaN                     NaN
# 3                         NaN                   NaN                     NaN
# 4                       868.0                 241.0                    0.38
# ...                       ...                   ...                     ...
# 97270                     NaN                   NaN                     NaN
# 97271                     NaN                   NaN                     NaN
# 97272                     NaN                   NaN                     NaN
# 97273                     NaN                   NaN                     NaN
# 97274                     NaN                   NaN                     NaN
#
# [97275 rows x 16 columns]

# %% [markdown]
# # Use Rise of Kingdoms as the test game

# %%
raw_game_data_df[raw_game_data_df["Unified Name"] == "Rise of Kingdoms"]
# Out:
#            Unified Name                Unified ID Unified Publisher Name  \
# 3337   Rise of Kingdoms  5ac2bdddcfc03208313848db             Lilith 莉莉丝
# 10000  Rise of Kingdoms  5ac2bdddcfc03208313848db             Lilith 莉莉丝
# 26664  Rise of Kingdoms  5ac2bdddcfc03208313848db             Lilith 莉莉丝
# 37320  Rise of Kingdoms  5ac2bdddcfc03208313848db             Lilith 莉莉丝
# 46069  Rise of Kingdoms  5ac2bdddcfc03208313848db             Lilith 莉莉丝
# 53985  Rise of Kingdoms  5ac2bdddcfc03208313848db             Lilith 莉莉丝
# 66676  Rise of Kingdoms  5ac2bdddcfc03208313848db             Lilith 莉莉丝
#
#            Unified Publisher ID       Date Platform  Category  \
# 3337   59418862660953716600e6f7 2024-01-01  Unified     Games
# 10000  59418862660953716600e6f7 2023-01-01  Unified  Strategy
# 26664  59418862660953716600e6f7 2022-01-01  Unified     Games
# 37320  59418862660953716600e6f7 2021-01-01  Unified     Games
# 46069  59418862660953716600e6f7 2020-01-01  Unified  Strategy
# 53985  59418862660953716600e6f7 2019-01-01  Unified     Games
# 66676  59418862660953716600e6f7 2018-01-01  Unified  Strategy
#
#        Downloads (Absolute)  Downloads (Growth)  Downloads (Growth %)  \
# 3337                 738234              -70916                 -0.09
# 10000                964015            -2295941                 -0.70
# 26664               3259956             3259956                   NaN
# 37320                323301            -2025318                 -0.86
# 46069               2348619              854175                  0.57
# 53985               1494444             1004453                  2.05
# 66676                489991              489991                   NaN
#
#        Revenue (Absolute, $)  Revenue (Growth, $)  Revenue (Growth %)  \
# 3337              3058963.86          -2076873.90               -0.40
# 10000             5892819.33          -2602197.56               -0.31
# 26664             8495016.89           8495016.89                 NaN
# 37320             4191293.14          -6048204.35               -0.59
# 46069            10239497.49           6808345.39                1.98
# 53985             3431152.10           2957736.96                6.25
# 66676              473415.14            473415.14                 NaN
#
#        Average DAU (Absolute)  Average DAU (Growth)  Average DAU (Growth %)
# 3337                  85507.0              -28668.0                   -0.25
# 10000                116927.0              -33522.0                   -0.22
# 26664                150449.0              150449.0                     NaN
# 37320                109406.0             -109996.0                   -0.50
# 46069                219443.0              124140.0                    1.30
# 53985                 95347.0               76264.0                    4.00
# 66676                 19083.0               19083.0                     NaN

# %%
rok_unified_id = "5ac2bdddcfc03208313848db"

# %%
# Another test case - Mobile Legends Bang Bang

# %%
raw_game_data_df[raw_game_data_df["Unified Name"] == "Mobile Legends: Bang Bang"]
# Out:
#                     Unified Name                Unified ID  \
# 3299   Mobile Legends: Bang Bang  57955d280211a6718a000002
# 16688  Mobile Legends: Bang Bang  57955d280211a6718a000002
# 26716  Mobile Legends: Bang Bang  57955d280211a6718a000002
# 37331  Mobile Legends: Bang Bang  57955d280211a6718a000002
# 46709  Mobile Legends: Bang Bang  57955d280211a6718a000002
# 53953  Mobile Legends: Bang Bang  57955d280211a6718a000002
# 66659  Mobile Legends: Bang Bang  57955d280211a6718a000002
# 72826  Mobile Legends: Bang Bang  57955d280211a6718a000002
# 84287  Mobile Legends: Bang Bang  57955d280211a6718a000002
#
#       Unified Publisher Name      Unified Publisher ID       Date Platform  \
# 3299              Moonton 沐瞳  62c4b457b3ae271ff6cc58a4 2024-01-01  Unified
# 16688             Moonton 沐瞳  62c4b457b3ae271ff6cc58a4 2023-01-01  Unified
# 26716             Moonton 沐瞳  62c4b457b3ae271ff6cc58a4 2022-01-01  Unified
# 37331             Moonton 沐瞳  62c4b457b3ae271ff6cc58a4 2021-01-01  Unified
# 46709             Moonton 沐瞳  62c4b457b3ae271ff6cc58a4 2020-01-01  Unified
# 53953             Moonton 沐瞳  62c4b457b3ae271ff6cc58a4 2019-01-01  Unified
# 66659             Moonton 沐瞳  62c4b457b3ae271ff6cc58a4 2018-01-01  Unified
# 72826             Moonton 沐瞳  62c4b457b3ae271ff6cc58a4 2017-01-01  Unified
# 84287             Moonton 沐瞳  62c4b457b3ae271ff6cc58a4 2016-01-01  Unified
#
#       Category  Downloads (Absolute)  Downloads (Growth)  \
# 3299    Action               3341367             1908518
# 16688   Action               1660020            -1022923
# 26716   Action               2682943             -715444
# 37331   Action               3398387            -1212747
# 46709   Action               4611134            -3006325
# 53953   Action               7617459             5380125
# 66659   Action               6948781             2507845
# 72826   Action               4440936             2242163
# 84287   Action               2198773             2198773
#
#        Downloads (Growth %)  Revenue (Absolute, $)  Revenue (Growth, $)  \
# 3299                   1.33              619308.61            149651.89
# 16688                 -0.38              545134.67             38457.72
# 26716                 -0.21              506676.95            -26647.66
# 37331                 -0.26              533324.61             88274.23
# 46709                 -0.39              445050.38             10956.14
# 53953                  2.40              434094.24            397793.32
# 66659                  0.56              422070.67            242829.81
# 72826                  1.02              179240.86            165464.34
# 84287                   NaN               13776.52             13776.52
#
#        Revenue (Growth %)  Average DAU (Absolute)  Average DAU (Growth)  \
# 3299                 0.32                647957.0              -71868.0
# 16688                0.08                747450.0             -202413.0
# 26716               -0.05                949863.0              114761.0
# 37331                0.20                835102.0              113208.0
# 46709                0.03                721362.0              203773.0
# 53953               10.96                518048.0              484510.0
# 66659                1.35                749404.0              260254.0
# 72826               12.01                489150.0              415207.0
# 84287                 NaN                 73741.0               73741.0
#
#        Average DAU (Growth %)
# 3299                    -0.10
# 16688                   -0.21
# 26716                    0.14
# 37331                    0.16
# 46709                    0.39
# 53953                   14.45
# 66659                    0.53
# 72826                    5.62
# 84287                     NaN

# %%
mlbb_unified_id = "57955d280211a6718a000002"

# %% [markdown]
# # Get all the local app id of this game

# %%
# Get unified app data first

unified_app_data = get_unified_app_data(
    api_key, base_url, ["5ac2bdddcfc03208313848db",]
)
# Out:
# making call for chunk number 1
# call successful!

# %%
unified_app_data
# Out:
# [{'unified_app_id': '5ac2bdddcfc03208313848db',
#   'name': 'Rise of Kingdoms',
#   'canonical_app_id': 1354260888,
#   'cohort_id': 'cohort_e98ab6fcac86cc1e1b6163cd',
#   'itunes_apps': [{'app_id': 1354260888},
#    {'app_id': 1519945981},
#    {'app_id': 1483025097},
#    {'app_id': 1474599374},
#    {'app_id': 1436964519},
#    {'app_id': 1574489575}],
#   'android_apps': [{'app_id': 'com.lilithgame.roc.gp'},
#    {'app_id': 'com.lilithgames.rok.gpkr'},
#    {'app_id': 'com.lilithgames.rok.gp.jp'},
#    {'app_id': 'com.lilithgame.roc.gp.tw'},
#    {'app_id': 'com.rok.gp.vn'}],
#   'unified_publisher_ids': ['59418862660953716600e6f7'],
#   'itunes_publisher_ids': [982119759,
#    1481453487,
#    982163649,
#    1478872809,
#    1377104229],
#   'android_publisher_ids': ['LilithGames', '奧瑞吉有限公司']}]

# %%
# Get app_id list

app_id_dict = get_app_id_lists(unified_app_data)

# %%
app_id_dict
# Out:
# {'ios_app_id_list': ['1354260888',
#   '1519945981',
#   '1483025097',
#   '1474599374',
#   '1436964519',
#   '1574489575'],
#  'android_app_id_list': ['com.lilithgame.roc.gp',
#   'com.lilithgames.rok.gpkr',
#   'com.lilithgames.rok.gp.jp',
#   'com.lilithgame.roc.gp.tw',
#   'com.rok.gp.vn']}

# %%
# Second test case - MLBB

# %%
unified_app_data = get_unified_app_data(
    api_key, base_url, ["57955d280211a6718a000002",]
)
# Out:
# making call for chunk number 1
# call successful!

# %%
unified_app_data
# Out:
# [{'unified_app_id': '57955d280211a6718a000002',
#   'name': 'Mobile Legends: Bang Bang',
#   'canonical_app_id': 'com.mobile.legends',
#   'cohort_id': 'cohort_62c5c2137664b3a4fd1a03ce',
#   'itunes_apps': [{'app_id': 1160056295},
#    {'app_id': 1428475506},
#    {'app_id': 6468942281},
#    {'app_id': 6670476964}],
#   'android_apps': [{'app_id': 'com.mobile.legends'},
#    {'app_id': 'com.vng.mlbbvn'},
#    {'app_id': 'com.mobiin.gp'},
#    {'app_id': 'com.hhgame.mlbbvn'}],
#   'unified_publisher_ids': ['562890fe02ac648b2800231f',
#    '5bc8740ca2750e2e014a1c19',
#    '61176426ca971556e3a545d2',
#    '62c4b457b3ae271ff6cc58a4',
#    '653425cf80474a233591b66b',
#    '66054d3dedca1062d05c2a61'],
#   'itunes_publisher_ids': [910435102, 398453277, 1438383758, 1706091894],
#   'android_publisher_ids': ['Moonton',
#    'VNG+Corporation+-+Công+ty+Cổ+phần+VNG',
#    'Vizta+Games',
#    'Công+ty+cổ+phần+phát+triển+công+nghệ+số+Hồng+Hà']}]

# %%
app_id_list = get_app_id_lists(unified_app_data)

# %%
app_id_list
# Out:
# [{'os': 'ios', 'app_id': '1160056295'},
#  {'os': 'ios', 'app_id': '1428475506'},
#  {'os': 'ios', 'app_id': '6468942281'},
#  {'os': 'ios', 'app_id': '6670476964'},
#  {'os': 'android', 'app_id': 'com.mobile.legends'},
#  {'os': 'android', 'app_id': 'com.vng.mlbbvn'},
#  {'os': 'android', 'app_id': 'com.mobiin.gp'},
#  {'os': 'android', 'app_id': 'com.hhgame.mlbbvn'}]

# %% [markdown]
# # Get all vn revenue streams of these local app id from the earliest possible date til now

# %%
rev_stream_test_rok = get_monthly_app_performance_single_app_id(
    api_key, 
    base_url, 
    os = 'ios', 
    app_id = '1160056295', 
    country_code = 'VN', 
    start_date = '2014-01-01', 
    end_date = '2024-10-31'
)
# Out:
# Getting performance data for app id 1160056295
# Date Ranges
# [('2014-01-01', '2014-12-27'), ('2014-12-28', '2015-12-23'), ('2015-12-24', '2016-12-18'), ('2016-12-19', '2017-12-14'), ('2017-12-15', '2018-12-10'), ('2018-12-11', '2019-12-06'), ('2019-12-07', '2020-12-01'), ('2020-12-02', '2021-11-27'), ('2021-11-28', '2022-11-23'), ('2022-11-24', '2023-11-19'), ('2023-11-20', '2024-10-31')]
# Data retrieved for 2014-01-01 to 2014-12-27
# Data retrieved for 2014-12-28 to 2015-12-23
# Data retrieved for 2015-12-24 to 2016-12-18
# Data retrieved for 2016-12-19 to 2017-12-14
# Data retrieved for 2017-12-15 to 2018-12-10
# Data retrieved for 2018-12-11 to 2019-12-06
# Data retrieved for 2019-12-07 to 2020-12-01
# Data retrieved for 2020-12-02 to 2021-11-27
# Data retrieved for 2021-11-28 to 2022-11-23
# Data retrieved for 2022-11-24 to 2023-11-19
# Data retrieved for 2023-11-20 to 2024-10-31

# %%
rev_stream_test_rok
# Out:
# [{'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-01-01T00:00:00Z',
#   'au': 23086,
#   'ar': 460301,
#   'iu': 102361,
#   'ir': 10080465},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-02-01T00:00:00Z',
#   'au': 25966,
#   'ar': 1635748,
#   'iu': 136643,
#   'ir': 37475506},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-03-01T00:00:00Z',
#   'au': 16315,
#   'ar': 2161656,
#   'iu': 107710,
#   'ir': 51266125},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-04-01T00:00:00Z',
#   'au': 8576,
#   'ar': 1978652,
#   'iu': 58726,
#   'ir': 59674095},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-05-01T00:00:00Z',
#   'au': 5727,
#   'ar': 2804362,
#   'iu': 40891,
#   'ir': 59764065},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-06-01T00:00:00Z',
#   'au': 5750,
#   'ar': 2227976,
#   'iu': 49684,
#   'ir': 51264123},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-07-01T00:00:00Z',
#   'au': 5360,
#   'ar': 2664741,
#   'iu': 43381,
#   'ir': 29318126},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-08-01T00:00:00Z',
#   'au': 4444,
#   'ar': 1920506,
#   'iu': 47189,
#   'ir': 22573587},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-09-01T00:00:00Z',
#   'au': 6587,
#   'ar': 2417749,
#   'iu': 69312,
#   'ir': 23414906},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-10-01T00:00:00Z',
#   'au': 6110,
#   'ar': 2235512,
#   'iu': 68655,
#   'ir': 19695037},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-11-01T00:00:00Z',
#   'au': 4043,
#   'ar': 2159405,
#   'iu': 45183,
#   'ir': 20182984},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-11-01T00:00:00Z',
#   'au': 4043,
#   'ar': 2159405,
#   'iu': 45183,
#   'ir': 20182984},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2022-12-01T00:00:00Z',
#   'au': 3507,
#   'ar': 1943375,
#   'iu': 40380,
#   'ir': 21521116},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-01-01T00:00:00Z',
#   'au': 4454,
#   'ar': 1922137,
#   'iu': 43005,
#   'ir': 20849682},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-02-01T00:00:00Z',
#   'au': 1605,
#   'ar': 2137290,
#   'iu': 22357,
#   'ir': 18700327},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-03-01T00:00:00Z',
#   'au': 2321,
#   'ar': 2376256,
#   'iu': 25304,
#   'ir': 20793716},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-04-01T00:00:00Z',
#   'au': 2271,
#   'ar': 1988184,
#   'iu': 24387,
#   'ir': 20611465},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-05-01T00:00:00Z',
#   'au': 2623,
#   'ar': 2384787,
#   'iu': 25324,
#   'ir': 18805263},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-06-01T00:00:00Z',
#   'au': 2776,
#   'ar': 2053358,
#   'iu': 25328,
#   'ir': 18574235},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-07-01T00:00:00Z',
#   'au': 4643,
#   'ar': 1831567,
#   'iu': 22031,
#   'ir': 17585119},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-08-01T00:00:00Z',
#   'au': 4704,
#   'ar': 1603849,
#   'iu': 27968,
#   'ir': 16140614},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-09-01T00:00:00Z',
#   'au': 1521,
#   'ar': 1813425,
#   'iu': 20008,
#   'ir': 16754248},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-10-01T00:00:00Z',
#   'au': 1996,
#   'ar': 1574577,
#   'iu': 26877,
#   'ir': 17438307},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-11-01T00:00:00Z',
#   'au': 2229,
#   'ar': 1623177,
#   'iu': 24891,
#   'ir': 16542649},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-11-01T00:00:00Z',
#   'au': 2229,
#   'ar': 1623177,
#   'iu': 24891,
#   'ir': 16542649},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2023-12-01T00:00:00Z',
#   'au': 2156,
#   'ar': 1598736,
#   'iu': 22954,
#   'ir': 17575895},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-01-01T00:00:00Z',
#   'au': 2736,
#   'ar': 1553508,
#   'iu': 26976,
#   'ir': 14826351},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-02-01T00:00:00Z',
#   'au': 3425,
#   'ar': 1693864,
#   'iu': 28674,
#   'ir': 14054934},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-03-01T00:00:00Z',
#   'au': 3468,
#   'ar': 2209573,
#   'iu': 26204,
#   'ir': 12627181},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-04-01T00:00:00Z',
#   'au': 2596,
#   'ar': 1654896,
#   'iu': 18721,
#   'ir': 9721321},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-05-01T00:00:00Z',
#   'au': 2248,
#   'ar': 1741758,
#   'iu': 19295,
#   'ir': 11560659},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-06-01T00:00:00Z',
#   'au': 2189,
#   'ar': 1986636,
#   'iu': 17713,
#   'ir': 13799244},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-07-01T00:00:00Z',
#   'au': 2371,
#   'ar': 1411624,
#   'iu': 27855,
#   'ir': 13543759},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-08-01T00:00:00Z',
#   'au': 3537,
#   'ar': 1866694,
#   'iu': 32510,
#   'ir': 12161247},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-09-01T00:00:00Z',
#   'au': 3609,
#   'ar': 1447766,
#   'iu': 29892,
#   'ir': 12413968},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-10-01T00:00:00Z',
#   'au': 3454,
#   'ar': 1494683,
#   'iu': 38636,
#   'ir': 12347255},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-11-01T00:00:00Z',
#   'au': 2610,
#   'ar': 1722007,
#   'iu': 29046,
#   'ir': 10650214},
#  {'aid': 1574489575,
#   'cc': 'VN',
#   'd': '2024-11-01T00:00:00Z',
#   'au': 2610,
#   'ar': 1722007,
#   'iu': 29046,
#   'ir': 10650214}]

# %%
# MLBB

# %%
performance_streams_mlbb = get_performance_streams_from_list_of_app_ids(
    api_key, 
    base_url, 
    country_code = "VN", 
    start_date = "2014-01-01", 
    end_date = "2024-10-31", 
    list_app_ids = app_id_list)
# Out:
# Getting performance data for app id 1160056295
# Data retrieved for 2014-01-01 to 2014-12-31
# Data retrieved for 2015-01-01 to 2015-12-31
# Data retrieved for 2016-01-01 to 2016-12-31
# Data retrieved for 2017-01-01 to 2017-12-31
# Data retrieved for 2018-01-01 to 2018-12-31
# Data retrieved for 2019-01-01 to 2019-12-31
# Data retrieved for 2020-01-01 to 2020-12-31
# Data retrieved for 2021-01-01 to 2021-12-31
# Data retrieved for 2022-01-01 to 2022-12-31
# Data retrieved for 2023-01-01 to 2023-12-31
# Data retrieved for 2024-01-01 to 2024-10-31
# Getting performance data for app id 1428475506
# Data retrieved for 2014-01-01 to 2014-12-31
# Data retrieved for 2015-01-01 to 2015-12-31
# Data retrieved for 2016-01-01 to 2016-12-31
# Data retrieved for 2017-01-01 to 2017-12-31
# Data retrieved for 2018-01-01 to 2018-12-31
# Data retrieved for 2019-01-01 to 2019-12-31
# Data retrieved for 2020-01-01 to 2020-12-31
# Data retrieved for 2021-01-01 to 2021-12-31
# Data retrieved for 2022-01-01 to 2022-12-31
# Data retrieved for 2023-01-01 to 2023-12-31
# Data retrieved for 2024-01-01 to 2024-10-31
# Getting performance data for app id 6468942281
# Data retrieved for 2014-01-01 to 2014-12-31
# Data retrieved for 2015-01-01 to 2015-12-31
# Data retrieved for 2016-01-01 to 2016-12-31
# Data retrieved for 2017-01-01 to 2017-12-31
# Data retrieved for 2018-01-01 to 2018-12-31
# Data retrieved for 2019-01-01 to 2019-12-31
# Data retrieved for 2020-01-01 to 2020-12-31
# Data retrieved for 2021-01-01 to 2021-12-31
# Data retrieved for 2022-01-01 to 2022-12-31
# Data retrieved for 2023-01-01 to 2023-12-31
# Data retrieved for 2024-01-01 to 2024-10-31
# Getting performance data for app id 6670476964
# Data retrieved for 2014-01-01 to 2014-12-31
# Data retrieved for 2015-01-01 to 2015-12-31
# Data retrieved for 2016-01-01 to 2016-12-31
# Data retrieved for 2017-01-01 to 2017-12-31
# Data retrieved for 2018-01-01 to 2018-12-31
# Data retrieved for 2019-01-01 to 2019-12-31
# Data retrieved for 2020-01-01 to 2020-12-31
# Data retrieved for 2021-01-01 to 2021-12-31
# Data retrieved for 2022-01-01 to 2022-12-31
# Data retrieved for 2023-01-01 to 2023-12-31
# Data retrieved for 2024-01-01 to 2024-10-31
# Getting performance data for app id com.mobile.legends
# Data retrieved for 2014-01-01 to 2014-12-31
# Data retrieved for 2015-01-01 to 2015-12-31
# Data retrieved for 2016-01-01 to 2016-12-31
# Data retrieved for 2017-01-01 to 2017-12-31
# Data retrieved for 2018-01-01 to 2018-12-31
# Data retrieved for 2019-01-01 to 2019-12-31
# Data retrieved for 2020-01-01 to 2020-12-31
# Data retrieved for 2021-01-01 to 2021-12-31
# Data retrieved for 2022-01-01 to 2022-12-31
# Data retrieved for 2023-01-01 to 2023-12-31
# Data retrieved for 2024-01-01 to 2024-10-31
# Getting performance data for app id com.vng.mlbbvn
# Data retrieved for 2014-01-01 to 2014-12-31
# Data retrieved for 2015-01-01 to 2015-12-31
# Data retrieved for 2016-01-01 to 2016-12-31
# Data retrieved for 2017-01-01 to 2017-12-31
# Data retrieved for 2018-01-01 to 2018-12-31
# Data retrieved for 2019-01-01 to 2019-12-31
# Data retrieved for 2020-01-01 to 2020-12-31
# Data retrieved for 2021-01-01 to 2021-12-31
# Data retrieved for 2022-01-01 to 2022-12-31
# Data retrieved for 2023-01-01 to 2023-12-31
# Data retrieved for 2024-01-01 to 2024-10-31
# Getting performance data for app id com.mobiin.gp
# Data retrieved for 2014-01-01 to 2014-12-31
# Data retrieved for 2015-01-01 to 2015-12-31
# Data retrieved for 2016-01-01 to 2016-12-31
# Data retrieved for 2017-01-01 to 2017-12-31
# Data retrieved for 2018-01-01 to 2018-12-31
# Data retrieved for 2019-01-01 to 2019-12-31
# Data retrieved for 2020-01-01 to 2020-12-31
# Data retrieved for 2021-01-01 to 2021-12-31
# Data retrieved for 2022-01-01 to 2022-12-31
# Data retrieved for 2023-01-01 to 2023-12-31
# Data retrieved for 2024-01-01 to 2024-10-31
# Getting performance data for app id com.hhgame.mlbbvn
# Data retrieved for 2014-01-01 to 2014-12-31
# Data retrieved for 2015-01-01 to 2015-12-31
# Data retrieved for 2016-01-01 to 2016-12-31
# Data retrieved for 2017-01-01 to 2017-12-31
# Data retrieved for 2018-01-01 to 2018-12-31
# Data retrieved for 2019-01-01 to 2019-12-31
# Data retrieved for 2020-01-01 to 2020-12-31
# Data retrieved for 2021-01-01 to 2021-12-31
# Data retrieved for 2022-01-01 to 2022-12-31
# Data retrieved for 2023-01-01 to 2023-12-31
# Data retrieved for 2024-01-01 to 2024-10-31

# %%
performance_streams_mlbb
# Out:
# [{'app_id': '1160056295',
#   'os': 'ios',
#   'app_performance': [{'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2016-11-01T00:00:00Z',
#     'au': 24985,
#     'ar': 50310,
#     'iu': 78417,
#     'ir': 75420},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2016-12-01T00:00:00Z',
#     'au': 10514,
#     'ar': 69644,
#     'iu': 34589,
#     'ir': 185899},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-01-01T00:00:00Z',
#     'au': 12067,
#     'ar': 153764,
#     'iu': 41489,
#     'ir': 153439},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-02-01T00:00:00Z',
#     'au': 7869,
#     'ar': 54206,
#     'iu': 34086,
#     'ir': 278801},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-03-01T00:00:00Z',
#     'au': 8853,
#     'ar': 55413,
#     'iu': 41640,
#     'ir': 258177},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-04-01T00:00:00Z',
#     'au': 9949,
#     'ar': 62824,
#     'iu': 46050,
#     'ir': 364728},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-05-01T00:00:00Z',
#     'au': 15253,
#     'ar': 119136,
#     'iu': 64959,
#     'ir': 509458},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-06-01T00:00:00Z',
#     'au': 17089,
#     'ar': 114572,
#     'iu': 70853,
#     'ir': 409877},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-07-01T00:00:00Z',
#     'au': 15897,
#     'ar': 93158,
#     'iu': 79693,
#     'ir': 374482},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-08-01T00:00:00Z',
#     'au': 10116,
#     'ar': 73262,
#     'iu': 55116,
#     'ir': 296348},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-09-01T00:00:00Z',
#     'au': 7469,
#     'ar': 148191,
#     'iu': 55025,
#     'ir': 344092},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-10-01T00:00:00Z',
#     'au': 11045,
#     'ar': 193413,
#     'iu': 62138,
#     'ir': 521928},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-11-01T00:00:00Z',
#     'au': 7632,
#     'ar': 97205,
#     'iu': 58217,
#     'ir': 296757},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2017-12-01T00:00:00Z',
#     'au': 10130,
#     'ar': 97326,
#     'iu': 59922,
#     'ir': 276320},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-01-01T00:00:00Z',
#     'au': 8350,
#     'ar': 98643,
#     'iu': 53422,
#     'ir': 502303},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-02-01T00:00:00Z',
#     'au': 13227,
#     'ar': 132539,
#     'iu': 69297,
#     'ir': 441248},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-03-01T00:00:00Z',
#     'au': 9000,
#     'ar': 119131,
#     'iu': 57471,
#     'ir': 361417},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-04-01T00:00:00Z',
#     'au': 7321,
#     'ar': 127659,
#     'iu': 57534,
#     'ir': 431944},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-05-01T00:00:00Z',
#     'au': 8684,
#     'ar': 147485,
#     'iu': 64968,
#     'ir': 456693},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-06-01T00:00:00Z',
#     'au': 12491,
#     'ar': 124795,
#     'iu': 87385,
#     'ir': 477565},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-07-01T00:00:00Z',
#     'au': 9519,
#     'ar': 115473,
#     'iu': 67635,
#     'ir': 400148},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-08-01T00:00:00Z',
#     'au': 7949,
#     'ar': 112117,
#     'iu': 60127,
#     'ir': 614880},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-09-01T00:00:00Z',
#     'au': 4701,
#     'ar': 129625,
#     'iu': 38032,
#     'ir': 584468},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-10-01T00:00:00Z',
#     'au': 4596,
#     'ar': 174418,
#     'iu': 42288,
#     'ir': 734972},
#    {'aid': 1160056295,
#     'cc': 'VN',
#     'd': '2018-11-01T00:00:00Z',
#     'au': 2651,
#     'ar': 45530,
#     'iu': 19602,
#     'ir': 185194}]},
#  {'app_id': '1428475506',
#   'os': 'ios',
#   'app_performance': [{'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2018-11-01T00:00:00Z',
#     'au': 14996,
#     'ar': 48577,
#     'iu': 97827,
#     'ir': 221096},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2018-12-01T00:00:00Z',
#     'au': 23232,
#     'ar': 121735,
#     'iu': 158872,
#     'ir': 771530},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-01-01T00:00:00Z',
#     'au': 25712,
#     'ar': 161703,
#     'iu': 153651,
#     'ir': 785096},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-02-01T00:00:00Z',
#     'au': 14430,
#     'ar': 101458,
#     'iu': 90740,
#     'ir': 714275},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-03-01T00:00:00Z',
#     'au': 7084,
#     'ar': 117818,
#     'iu': 60029,
#     'ir': 730705},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-04-01T00:00:00Z',
#     'au': 6497,
#     'ar': 109753,
#     'iu': 54732,
#     'ir': 1075808},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-05-01T00:00:00Z',
#     'au': 9753,
#     'ar': 108272,
#     'iu': 76830,
#     'ir': 658294},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-06-01T00:00:00Z',
#     'au': 11465,
#     'ar': 110853,
#     'iu': 76384,
#     'ir': 1015030},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-07-01T00:00:00Z',
#     'au': 8066,
#     'ar': 90939,
#     'iu': 61212,
#     'ir': 705239},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-08-01T00:00:00Z',
#     'au': 7894,
#     'ar': 186305,
#     'iu': 71820,
#     'ir': 1485605},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-09-01T00:00:00Z',
#     'au': 5342,
#     'ar': 122199,
#     'iu': 50426,
#     'ir': 1072870},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-10-01T00:00:00Z',
#     'au': 4442,
#     'ar': 117463,
#     'iu': 42150,
#     'ir': 690957},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-11-01T00:00:00Z',
#     'au': 5874,
#     'ar': 74489,
#     'iu': 56457,
#     'ir': 827109},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2019-12-01T00:00:00Z',
#     'au': 5829,
#     'ar': 153851,
#     'iu': 55444,
#     'ir': 1796279},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-01-01T00:00:00Z',
#     'au': 6987,
#     'ar': 126594,
#     'iu': 58157,
#     'ir': 1392593},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-02-01T00:00:00Z',
#     'au': 6603,
#     'ar': 170976,
#     'iu': 58497,
#     'ir': 1259018},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-03-01T00:00:00Z',
#     'au': 6839,
#     'ar': 221118,
#     'iu': 59565,
#     'ir': 1150257},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-04-01T00:00:00Z',
#     'au': 7213,
#     'ar': 163390,
#     'iu': 60598,
#     'ir': 1458010},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-05-01T00:00:00Z',
#     'au': 7681,
#     'ar': 155168,
#     'iu': 62862,
#     'ir': 1395572},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-06-01T00:00:00Z',
#     'au': 4027,
#     'ar': 152649,
#     'iu': 39572,
#     'ir': 1006526},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-07-01T00:00:00Z',
#     'au': 5592,
#     'ar': 138037,
#     'iu': 49457,
#     'ir': 903050},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-08-01T00:00:00Z',
#     'au': 6138,
#     'ar': 160770,
#     'iu': 58710,
#     'ir': 1345296},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-09-01T00:00:00Z',
#     'au': 3478,
#     'ar': 133122,
#     'iu': 37680,
#     'ir': 954127},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-10-01T00:00:00Z',
#     'au': 3101,
#     'ar': 92301,
#     'iu': 34364,
#     'ir': 740394},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-11-01T00:00:00Z',
#     'au': 3383,
#     'ar': 90100,
#     'iu': 36328,
#     'ir': 922262},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2020-12-01T00:00:00Z',
#     'au': 3218,
#     'ar': 124138,
#     'iu': 35683,
#     'ir': 711003},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-01-01T00:00:00Z',
#     'au': 3916,
#     'ar': 97007,
#     'iu': 40340,
#     'ir': 541835},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-02-01T00:00:00Z',
#     'au': 4741,
#     'ar': 106115,
#     'iu': 49652,
#     'ir': 838263},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-03-01T00:00:00Z',
#     'au': 3113,
#     'ar': 94100,
#     'iu': 30753,
#     'ir': 615622},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-04-01T00:00:00Z',
#     'au': 3068,
#     'ar': 130743,
#     'iu': 31212,
#     'ir': 808147},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-05-01T00:00:00Z',
#     'au': 6275,
#     'ar': 143492,
#     'iu': 65307,
#     'ir': 1525152},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-06-01T00:00:00Z',
#     'au': 5315,
#     'ar': 115962,
#     'iu': 50809,
#     'ir': 1165161},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-07-01T00:00:00Z',
#     'au': 5188,
#     'ar': 143789,
#     'iu': 53456,
#     'ir': 1229462},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-08-01T00:00:00Z',
#     'au': 5398,
#     'ar': 140054,
#     'iu': 49867,
#     'ir': 1185744},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-09-01T00:00:00Z',
#     'au': 5326,
#     'ar': 124595,
#     'iu': 37825,
#     'ir': 1409005},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-10-01T00:00:00Z',
#     'au': 6371,
#     'ar': 145823,
#     'iu': 35761,
#     'ir': 1106616},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-11-01T00:00:00Z',
#     'au': 5764,
#     'ar': 147644,
#     'iu': 32674,
#     'ir': 1546840},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2021-12-01T00:00:00Z',
#     'au': 4729,
#     'ar': 182959,
#     'iu': 31544,
#     'ir': 1683311},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-01-01T00:00:00Z',
#     'au': 6026,
#     'ar': 190753,
#     'iu': 37946,
#     'ir': 1319474},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-02-01T00:00:00Z',
#     'au': 5138,
#     'ar': 186819,
#     'iu': 30749,
#     'ir': 1014454},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-03-01T00:00:00Z',
#     'au': 4353,
#     'ar': 184203,
#     'iu': 35673,
#     'ir': 921999},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-04-01T00:00:00Z',
#     'au': 4319,
#     'ar': 213125,
#     'iu': 35065,
#     'ir': 1628185},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-05-01T00:00:00Z',
#     'au': 5965,
#     'ar': 189748,
#     'iu': 44769,
#     'ir': 1484719},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-06-01T00:00:00Z',
#     'au': 5823,
#     'ar': 131864,
#     'iu': 38562,
#     'ir': 1051453},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-07-01T00:00:00Z',
#     'au': 5383,
#     'ar': 167861,
#     'iu': 38860,
#     'ir': 1161852},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-08-01T00:00:00Z',
#     'au': 5034,
#     'ar': 202899,
#     'iu': 38995,
#     'ir': 1140455},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-09-01T00:00:00Z',
#     'au': 2578,
#     'ar': 165984,
#     'iu': 25379,
#     'ir': 1022343},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-10-01T00:00:00Z',
#     'au': 2326,
#     'ar': 233123,
#     'iu': 24840,
#     'ir': 1266867},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-11-01T00:00:00Z',
#     'au': 2008,
#     'ar': 214887,
#     'iu': 22756,
#     'ir': 1439757},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2022-12-01T00:00:00Z',
#     'au': 2089,
#     'ar': 229463,
#     'iu': 22663,
#     'ir': 1257859},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-01-01T00:00:00Z',
#     'au': 2330,
#     'ar': 238647,
#     'iu': 26248,
#     'ir': 1312964},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-02-01T00:00:00Z',
#     'au': 1951,
#     'ar': 198418,
#     'iu': 23807,
#     'ir': 1306658},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-03-01T00:00:00Z',
#     'au': 1905,
#     'ar': 202753,
#     'iu': 22830,
#     'ir': 1308793},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-04-01T00:00:00Z',
#     'au': 1914,
#     'ar': 226702,
#     'iu': 29354,
#     'ir': 1637427},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-05-01T00:00:00Z',
#     'au': 2228,
#     'ar': 181115,
#     'iu': 32522,
#     'ir': 1101070},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-06-01T00:00:00Z',
#     'au': 2909,
#     'ar': 167092,
#     'iu': 35302,
#     'ir': 927367},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-07-01T00:00:00Z',
#     'au': 2791,
#     'ar': 155345,
#     'iu': 25376,
#     'ir': 1122145},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-08-01T00:00:00Z',
#     'au': 2225,
#     'ar': 205210,
#     'iu': 23998,
#     'ir': 1102330},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-09-01T00:00:00Z',
#     'au': 1166,
#     'ar': 158216,
#     'iu': 21755,
#     'ir': 1266119},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-10-01T00:00:00Z',
#     'au': 1037,
#     'ar': 253388,
#     'iu': 20031,
#     'ir': 1414940},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-11-01T00:00:00Z',
#     'au': 1607,
#     'ar': 282677,
#     'iu': 19483,
#     'ir': 1631901},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2023-12-01T00:00:00Z',
#     'au': 1835,
#     'ar': 245844,
#     'iu': 23590,
#     'ir': 1917606},
#    {'aid': 1428475506,
#     'cc': 'VN',
#     'd': '2024-01-01T00:00:00Z',
#     'au': 1545,
#     'ar': 167636,
#     'iu': 21436,
#     'ir': 1281665}]},
#  {'app_id': '6468942281',
#   'os': 'ios',
#   'app_performance': [{'aid': 6468942281,
#     'cc': 'VN',
#     'd': '2024-02-01T00:00:00Z',
#     'au': 887,
#     'ar': 28142,
#     'iu': 11040,
#     'ir': 134926},
#    {'aid': 6468942281,
#     'cc': 'VN',
#     'd': '2024-03-01T00:00:00Z',
#     'au': 2565,
#     'ar': 171283,
#     'iu': 33945,
#     'ir': 1008579},
#    {'aid': 6468942281,
#     'cc': 'VN',
#     'd': '2024-04-01T00:00:00Z',
#     'au': 4063,
#     'ar': 254727,
#     'iu': 32877,
#     'ir': 1392171},
#    {'aid': 6468942281,
#     'cc': 'VN',
#     'd': '2024-05-01T00:00:00Z',
#     'au': 3554,
#     'ar': 225253,
#     'iu': 36180,
#     'ir': 1354735},
#    {'aid': 6468942281,
#     'cc': 'VN',
#     'd': '2024-06-01T00:00:00Z',
#     'au': 4258,
#     'ar': 197899,
#     'iu': 35047,
#     'ir': 1797519},
#    {'aid': 6468942281,
#     'cc': 'VN',
#     'd': '2024-07-01T00:00:00Z',
#     'au': 4380,
#     'ar': 235332,
#     'iu': 43484,
#     'ir': 1889321},
#    {'aid': 6468942281,
#     'cc': 'VN',
#     'd': '2024-08-01T00:00:00Z',
#     'au': 5577,
#     'ar': 154346,
#     'iu': 52671,
#     'ir': 1347754},
#    {'aid': 6468942281,
#     'cc': 'VN',
#     'd': '2024-09-01T00:00:00Z',
#     'au': 5225,
#     'ar': 150884,
#     'iu': 61155,
#     'ir': 1430811},
#    {'aid': 6468942281,
#     'cc': 'VN',
#     'd': '2024-10-01T00:00:00Z',
#     'au': 4201,
#     'ar': 136663,
#     'iu': 53071,
#     'ir': 1588161}]},
#  {'app_id': '6670476964', 'os': 'ios', 'app_performance': []},
#  {'app_id': 'com.mobile.legends',
#   'os': 'android',
#   'app_performance': [{'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2016-09-01T00:00:00Z',
#     'u': 56949,
#     'r': 457},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2016-10-01T00:00:00Z',
#     'u': 978601,
#     'r': 175431},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2016-11-01T00:00:00Z',
#     'u': 559107,
#     'r': 337236},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2016-12-01T00:00:00Z',
#     'u': 455611,
#     'r': 483255},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-01-01T00:00:00Z',
#     'u': 222313,
#     'r': 619205},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-02-01T00:00:00Z',
#     'u': 199936,
#     'r': 640954},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-03-01T00:00:00Z',
#     'u': 223070,
#     'r': 654582},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-04-01T00:00:00Z',
#     'u': 241438,
#     'r': 960917},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-05-01T00:00:00Z',
#     'u': 352858,
#     'r': 1119389},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-06-01T00:00:00Z',
#     'u': 391541,
#     'r': 1210556},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-07-01T00:00:00Z',
#     'u': 393793,
#     'r': 1250847},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-08-01T00:00:00Z',
#     'u': 367249,
#     'r': 1306298},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-09-01T00:00:00Z',
#     'u': 325233,
#     'r': 1439489},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-10-01T00:00:00Z',
#     'u': 305151,
#     'r': 1218659},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-11-01T00:00:00Z',
#     'u': 298120,
#     'r': 1049504},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2017-12-01T00:00:00Z',
#     'u': 317677,
#     'r': 1106809},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-01-01T00:00:00Z',
#     'u': 254515,
#     'r': 1087572},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-02-01T00:00:00Z',
#     'u': 390160,
#     'r': 1282221},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-03-01T00:00:00Z',
#     'u': 324616,
#     'r': 1392037},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-04-01T00:00:00Z',
#     'u': 323627,
#     'r': 1910912},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-05-01T00:00:00Z',
#     'u': 365873,
#     'r': 11655596},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-06-01T00:00:00Z',
#     'u': 442827,
#     'r': 7705620},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-07-01T00:00:00Z',
#     'u': 535767,
#     'r': 1355750},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-08-01T00:00:00Z',
#     'u': 440769,
#     'r': 1240750},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-09-01T00:00:00Z',
#     'u': 368158,
#     'r': 1830819},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-10-01T00:00:00Z',
#     'u': 357258,
#     'r': 1636675},
#    {'aid': 'com.mobile.legends',
#     'c': 'VN',
#     'd': '2018-11-01T00:00:00Z',
#     'u': 201627,
#     'r': 960776}]},
#  {'app_id': 'com.vng.mlbbvn',
#   'os': 'android',
#   'app_performance': [{'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2018-11-01T00:00:00Z',
#     'u': 469377,
#     'r': 312622},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2018-12-01T00:00:00Z',
#     'u': 1473030,
#     'r': 2154532},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-01-01T00:00:00Z',
#     'u': 1235003,
#     'r': 2222453},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-02-01T00:00:00Z',
#     'u': 833571,
#     'r': 2788890},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-03-01T00:00:00Z',
#     'u': 575374,
#     'r': 2154188},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-04-01T00:00:00Z',
#     'u': 489464,
#     'r': 1783517},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-05-01T00:00:00Z',
#     'u': 571265,
#     'r': 2641726},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-06-01T00:00:00Z',
#     'u': 687754,
#     'r': 3400983},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-07-01T00:00:00Z',
#     'u': 597578,
#     'r': 2651632},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-08-01T00:00:00Z',
#     'u': 469667,
#     'r': 4346237},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-09-01T00:00:00Z',
#     'u': 268742,
#     'r': 3207381},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-10-01T00:00:00Z',
#     'u': 249022,
#     'r': 2106209},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-11-01T00:00:00Z',
#     'u': 269217,
#     'r': 1494041},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2019-12-01T00:00:00Z',
#     'u': 408539,
#     'r': 1599797},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-01-01T00:00:00Z',
#     'u': 455224,
#     'r': 1552071},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-02-01T00:00:00Z',
#     'u': 477636,
#     'r': 1673688},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-03-01T00:00:00Z',
#     'u': 469779,
#     'r': 1747249},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-04-01T00:00:00Z',
#     'u': 486382,
#     'r': 2179412},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-05-01T00:00:00Z',
#     'u': 363987,
#     'r': 3764577},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-06-01T00:00:00Z',
#     'u': 322391,
#     'r': 2516291},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-07-01T00:00:00Z',
#     'u': 313803,
#     'r': 2710388},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-08-01T00:00:00Z',
#     'u': 294836,
#     'r': 3515888},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-09-01T00:00:00Z',
#     'u': 212297,
#     'r': 2954988},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-10-01T00:00:00Z',
#     'u': 211607,
#     'r': 2236680},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-11-01T00:00:00Z',
#     'u': 186573,
#     'r': 2371565},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2020-12-01T00:00:00Z',
#     'u': 160886,
#     'r': 2315770},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-01-01T00:00:00Z',
#     'u': 153836,
#     'r': 1749192},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-02-01T00:00:00Z',
#     'u': 237217,
#     'r': 2453094},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-03-01T00:00:00Z',
#     'u': 198430,
#     'r': 2129589},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-04-01T00:00:00Z',
#     'u': 185808,
#     'r': 2315158},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-05-01T00:00:00Z',
#     'u': 244090,
#     'r': 3651604},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-06-01T00:00:00Z',
#     'u': 272749,
#     'r': 3516706},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-07-01T00:00:00Z',
#     'u': 284895,
#     'r': 3877469},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-08-01T00:00:00Z',
#     'u': 275845,
#     'r': 3084193},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-09-01T00:00:00Z',
#     'u': 280532,
#     'r': 2980442},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-10-01T00:00:00Z',
#     'u': 283709,
#     'r': 1960172},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-11-01T00:00:00Z',
#     'u': 195859,
#     'r': 5643092},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2021-12-01T00:00:00Z',
#     'u': 217013,
#     'r': 4744309},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-01-01T00:00:00Z',
#     'u': 272394,
#     'r': 3651607},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-02-01T00:00:00Z',
#     'u': 201458,
#     'r': 3954173},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-03-01T00:00:00Z',
#     'u': 225812,
#     'r': 2993803},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-04-01T00:00:00Z',
#     'u': 215888,
#     'r': 3927767},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-05-01T00:00:00Z',
#     'u': 211129,
#     'r': 3437423},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-06-01T00:00:00Z',
#     'u': 220561,
#     'r': 2203194},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-07-01T00:00:00Z',
#     'u': 228008,
#     'r': 1957036},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-08-01T00:00:00Z',
#     'u': 202665,
#     'r': 2089770},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-09-01T00:00:00Z',
#     'u': 138680,
#     'r': 1220630},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-10-01T00:00:00Z',
#     'u': 112931,
#     'r': 2617758},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-11-01T00:00:00Z',
#     'u': 105491,
#     'r': 2922188},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2022-12-01T00:00:00Z',
#     'u': 100627,
#     'r': 2672200},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-01-01T00:00:00Z',
#     'u': 143352,
#     'r': 3626960},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-02-01T00:00:00Z',
#     'u': 98881,
#     'r': 3067564},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-03-01T00:00:00Z',
#     'u': 114427,
#     'r': 3278572},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-04-01T00:00:00Z',
#     'u': 110656,
#     'r': 3897732},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-05-01T00:00:00Z',
#     'u': 129928,
#     'r': 2715377},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-06-01T00:00:00Z',
#     'u': 138276,
#     'r': 2240834},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-07-01T00:00:00Z',
#     'u': 120774,
#     'r': 2543902},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-08-01T00:00:00Z',
#     'u': 117910,
#     'r': 2427761},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-09-01T00:00:00Z',
#     'u': 99237,
#     'r': 2497276},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-10-01T00:00:00Z',
#     'u': 84031,
#     'r': 2753636},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-11-01T00:00:00Z',
#     'u': 81812,
#     'r': 3661865},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2023-12-01T00:00:00Z',
#     'u': 92542,
#     'r': 3237261},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2024-01-01T00:00:00Z',
#     'u': 112118,
#     'r': 2863411},
#    {'aid': 'com.vng.mlbbvn',
#     'c': 'VN',
#     'd': '2024-02-01T00:00:00Z',
#     'u': 8752,
#     'r': 978}]},
#  {'app_id': 'com.mobiin.gp', 'os': 'android', 'app_performance': []},
#  {'app_id': 'com.hhgame.mlbbvn',
#   'os': 'android',
#   'app_performance': [{'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-02-01T00:00:00Z',
#     'u': 124991,
#     'r': 2521078},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-03-01T00:00:00Z',
#     'u': 198971,
#     'r': 4628527},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-04-01T00:00:00Z',
#     'u': 261751,
#     'r': 5161661},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-05-01T00:00:00Z',
#     'u': 257491,
#     'r': 4660375},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-06-01T00:00:00Z',
#     'u': 311127,
#     'r': 4305700},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-07-01T00:00:00Z',
#     'u': 421596,
#     'r': 4871071},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-08-01T00:00:00Z',
#     'u': 352100,
#     'r': 3921492},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-09-01T00:00:00Z',
#     'u': 417389,
#     'r': 3386111},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-10-01T00:00:00Z',
#     'u': 325647,
#     'r': 5735495}]}]

# %%
list(filter(lambda x: x['app_id'] == 'com.hhgame.mlbbvn', performance_streams_mlbb))
# Out:
# [{'app_id': 'com.hhgame.mlbbvn',
#   'os': 'android',
#   'app_performance': [{'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-02-01T00:00:00Z',
#     'u': 124991,
#     'r': 2521078},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-03-01T00:00:00Z',
#     'u': 198971,
#     'r': 4628527},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-04-01T00:00:00Z',
#     'u': 261751,
#     'r': 5161661},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-05-01T00:00:00Z',
#     'u': 257491,
#     'r': 4660375},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-06-01T00:00:00Z',
#     'u': 311127,
#     'r': 4305700},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-07-01T00:00:00Z',
#     'u': 421596,
#     'r': 4871071},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-08-01T00:00:00Z',
#     'u': 352100,
#     'r': 3921492},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-09-01T00:00:00Z',
#     'u': 417389,
#     'r': 3386111},
#    {'aid': 'com.hhgame.mlbbvn',
#     'c': 'VN',
#     'd': '2024-10-01T00:00:00Z',
#     'u': 325647,
#     'r': 5735495}]}]

# %% [markdown]
# # Turn performance stream list of dictionary to dataframe table form

# %%
# Get all the unique dates

# %%
unique_dates = get_unique_dates(performance_streams_mlbb)

# %%
app_ids = get_app_ids_from_performance_stream_data(performance_streams_mlbb)

# %%
df_performance_streams_mlbb = pd.DataFrame(index=app_ids, columns=unique_dates)

# %%
def fill_performance_streams_df(blank_df, performance_streams_data):
    for row in performance_streams_data:
        if row['os'] == 'ios':
            for record in row['app_performance']:        
                blank_df.at[row['app_id'], record['d']] = record['ar'] + record['ir']
        elif row['os'] == 'android':
            for record in row['app_performance']:        
                blank_df.at[row['app_id'], record['d']] = record['r']

# %%
df_performance_streams_mlbb
# Out:
#                    2016-09-01T00:00:00Z 2016-10-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2016-11-01T00:00:00Z 2016-12-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2017-01-01T00:00:00Z 2017-02-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2017-03-01T00:00:00Z 2017-04-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2017-05-01T00:00:00Z 2017-06-01T00:00:00Z  ...  \
# 1160056295                          NaN                  NaN  ...
# 1428475506                          NaN                  NaN  ...
# 6468942281                          NaN                  NaN  ...
# 6670476964                          NaN                  NaN  ...
# com.mobile.legends                  NaN                  NaN  ...
# com.vng.mlbbvn                      NaN                  NaN  ...
# com.mobiin.gp                       NaN                  NaN  ...
# com.hhgame.mlbbvn                   NaN                  NaN  ...
#
#                    2024-01-01T00:00:00Z 2024-02-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2024-03-01T00:00:00Z 2024-04-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2024-05-01T00:00:00Z 2024-06-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2024-07-01T00:00:00Z 2024-08-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2024-09-01T00:00:00Z 2024-10-01T00:00:00Z
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
# [8 rows x 98 columns]

# %%
fill_performance_streams_df(df_performance_streams_mlbb, performance_streams_mlbb)

# %%
df_performance_streams_mlbb
# Out:
#                    2016-09-01T00:00:00Z 2016-10-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends                  457               175431
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2016-11-01T00:00:00Z 2016-12-01T00:00:00Z  \
# 1160056295                       125730               255543
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends               337236               483255
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2017-01-01T00:00:00Z 2017-02-01T00:00:00Z  \
# 1160056295                       307203               333007
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends               619205               640954
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2017-03-01T00:00:00Z 2017-04-01T00:00:00Z  \
# 1160056295                       313590               427552
# 1428475506                          NaN                  NaN
# 6468942281                          NaN                  NaN
# 6670476964                          NaN                  NaN
# com.mobile.legends               654582               960917
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN                  NaN
#
#                    2017-05-01T00:00:00Z 2017-06-01T00:00:00Z  ...  \
# 1160056295                       628594               524449  ...
# 1428475506                          NaN                  NaN  ...
# 6468942281                          NaN                  NaN  ...
# 6670476964                          NaN                  NaN  ...
# com.mobile.legends              1119389              1210556  ...
# com.vng.mlbbvn                      NaN                  NaN  ...
# com.mobiin.gp                       NaN                  NaN  ...
# com.hhgame.mlbbvn                   NaN                  NaN  ...
#
#                    2024-01-01T00:00:00Z 2024-02-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                      1449301                  NaN
# 6468942281                          NaN               163068
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                  2863411                  978
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn                   NaN              2521078
#
#                    2024-03-01T00:00:00Z 2024-04-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                      1179862              1646898
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn               4628527              5161661
#
#                    2024-05-01T00:00:00Z 2024-06-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                      1579988              1995418
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn               4660375              4305700
#
#                    2024-07-01T00:00:00Z 2024-08-01T00:00:00Z  \
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                      2124653              1502100
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn               4871071              3921492
#
#                    2024-09-01T00:00:00Z 2024-10-01T00:00:00Z
# 1160056295                          NaN                  NaN
# 1428475506                          NaN                  NaN
# 6468942281                      1581695              1724824
# 6670476964                          NaN                  NaN
# com.mobile.legends                  NaN                  NaN
# com.vng.mlbbvn                      NaN                  NaN
# com.mobiin.gp                       NaN                  NaN
# com.hhgame.mlbbvn               3386111              5735495
#
# [8 rows x 98 columns]

# %%
df_performance_streams_mlbb.to_excel('data/output/df_performance_streams_mlbb.xlsx', index=True)

# %%
# Now when each game is representaed by a table of revenue stream, 
# can just multiply the row by respective revenue multiplier of the app id

# %% [markdown]
# # Load revenue multiplier file

# %%
data_types = {
    "cleaned_publisher_name": "string",
    "publisher_id": "string",
    "publisher_name": "string",
    "revenue_multiplier": "int64"
}

# %%
df_revenue_multiplier = pd.read_csv(
    "data/revenue_multiplier.csv",
    dtype = data_types
)

# %%
df_revenue_multiplier
# Out:
#              cleaned_publisher_name               publisher_id  \
# 0                         CMNOnline                 1490674259
# 1                         CMNOnline                     CMN+G1
# 2                         CMNOnline                 CMN+Online
# 3    CTCP Giai Tri Thien Thuong Hoa                 1580495122
# 4    CTCP Giai Tri Thien Thuong Hoa                 1604321544
# ..                              ...                        ...
# 131                             VTC            VTC+Online,.JSC
# 132                        ZingPlay                 1600022992
# 133                        ZingPlay  VNG+ZingPlay+Game+Studios
# 134                        ZingPlay        VNG+ZingPlay+Studio
# 135                        ZingPlay           ZINGPLAY+VIETNAM
#
#                                         publisher_name  revenue_multiplier
# 0                                            CMNOnline                   1
# 1                                               CMN G1                   1
# 2                                           CMN Online                   1
# 3    THIEN THUONG HOA ENTERTAINMENT JOINT STOCK COM...                   3
# 4                                           Watt Games                   3
# ..                                                 ...                 ...
# 131                                    VTC Online,.JSC                   3
# 132                                   ZingPlay VietNam                  20
# 133                          VNG ZingPlay Game Studios                  20
# 134                                VNG ZingPlay Studio                  20
# 135                                   ZINGPLAY VIETNAM                  20
#
# [136 rows x 4 columns]

# %%
# Create a dictionary of publisher_id - multiplier

# %%
dict_publisher_id_revenue_multiplier = dict()

for index, row in df_revenue_multiplier.iterrows():
    dict_publisher_id_revenue_multiplier[row['publisher_id']] = row['revenue_multiplier']

# %%
dict_publisher_id_revenue_multiplier
# Out:
# {'1490674259': 1,
#  'CMN+G1': 1,
#  'CMN+Online': 1,
#  '1580495122': 3,
#  '1604321544': 3,
#  '1646907857': 3,
#  '1689532424': 3,
#  'CHUANG+COOL+ENTERTAINMENT': 3,
#  'TTH+GAME': 3,
#  'TTH+GAMES': 3,
#  'TTH+PLAY': 3,
#  'TTH+PLAY+COMPANY+LIMITED': 3,
#  'TTHmobi': 3,
#  'TTHOA+GAMES': 3,
#  'TTHOAGames': 3,
#  '959827394': 3,
#  'DZOGAME+Viet+Nam': 3,
#  '1091188713': 3,
#  '1473783022': 3,
#  '1682431193': 3,
#  'Công+ty+cổ+phần+Funtap': 3,
#  'Funtap.vn': 3,
#  'Funtap++Games': 3,
#  '790194591': 3,
#  '896628171': 3,
#  '982163649': 3,
#  '1418348199': 3,
#  '1547396692': 3,
#  '1549148665': 3,
#  '1676603715': 3,
#  '4GAMOTA': 3,
#  'APPOTA+INC': 3,
#  'GAMOTA+INC': 3,
#  'HTD+Media+VN': 3,
#  'LilithGames': 3,
#  '513828660': 15,
#  '1047094789': 15,
#  '1096472396': 15,
#  '1335627134': 15,
#  'Garena+Games+Online': 15,
#  'Garena+International+I': 15,
#  'Garena+Mobile+Private': 15,
#  '1475616011': 3,
#  '1547943738': 3,
#  'GOSU+Jsc': 3,
#  'GOSU+ONLINE+CORPORATION': 3,
#  'GOSU+Publisher': 3,
#  'Mobi389+-+GOSU': 3,
#  '1438383758': 3,
#  '1607282322': 3,
#  '1698482899': 3,
#  '1764913957': 3,
#  'Công+ty+cổ+phần+phát+triển+công+nghệ+số+Hồng+Hà': 3,
#  'CÔNG+TY+TNHH+CÔNG+NGHỆ+VÀ+DỊCH+VỤ+HỒNG+HÀ': 3,
#  'HHGAME+LTD': 3,
#  'Hong+Ha+game': 3,
#  'Hồng+Hà+Game': 3,
#  'Hồng+Hà+JSC': 3,
#  'HONG+HA+LTD': 3,
#  'Hong+Ha+VN': 3,
#  '1541584827': 1,
#  'Migame+Online': 1,
#  'MIGAME+STORE': 1,
#  '1584269063': 1,
#  'MuuGame': 1,
#  '1460367655': 3,
#  '1633610594': 3,
#  'SOHAGAME': 3,
#  'UCOOL+LIMITED': 3,
#  '1573708736': 1,
#  'Travellet+Online': 1,
#  'Travellet+VN': 1,
#  'TRAVELLETVN\xa0GAMES': 1,
#  'TravelletVN+GAME': 1,
#  'VN+Travellet': 1,
#  '1055271558': 3,
#  'VGP+Company': 3,
#  'VGP+Corporation': 3,
#  'VGP+GENZ+JSC': 3,
#  'VGP+INC': 3,
#  'VGP+JSC+INC': 3,
#  'VGP+NLK+JSC': 3,
#  'VGPJSC': 3,
#  '1604141847': 1,
#  '1682210100': 1,
#  '1698479273': 1,
#  '1720343838': 1,
#  '1724147044': 1,
#  'Vision+Game+Joint+Stock+Company': 1,
#  'Vision+Net': 1,
#  'VISION+NETWORK+VIET+NAM.,JSC': 1,
#  'VisionNetwork': 1,
#  '398453277': 10,
#  '717106260': 10,
#  '1528287523': 10,
#  '1556247038': 10,
#  'MINH+PHUONG+THINH+COMMUNICATION+COMPANY+LIMITED': 10,
#  'VINA+GAMES': 10,
#  'VNG+-+Game+Studio+North': 10,
#  'VNG+Corporation': 10,
#  'VNG+Corporation+-+Công+ty+Cổ+phần+VNG': 10,
#  'VNG+Game+Publishing': 10,
#  'VNG+Game+Studio+North': 10,
#  'VNG+Game+Studios': 10,
#  'VNG+GAME+STUDIOS+SEA': 10,
#  'VNG+Games': 10,
#  'VNG+Gunny': 10,
#  'VNG+Mobile+.,Inc': 10,
#  'VNG+Mobile+Game+Studio': 10,
#  'VNG+Mobile+Studio': 10,
#  'VNGGame': 10,
#  'VNGGame+Contra': 10,
#  'VNGGames+International': 10,
#  'VNGGames+Studios': 10,
#  '874819657': 3,
#  'Vietnam+Interactive+Television+JSC': 3,
#  'VPLAY': 3,
#  '371962663': 3,
#  '470556954': 3,
#  '607974350': 3,
#  '869225534': 3,
#  '1162116447': 3,
#  '1267784899': 3,
#  'Magmatic+Games+LTD': 3,
#  'Moon+Active': 3,
#  'Playrix': 3,
#  'VTC+GAme': 3,
#  'VTC+Mobile+-+Mobile+Game+Center': 3,
#  'VTC+Mobile+Company': 3,
#  'VTC+Mobile+Entertainment+&+Sport+Center': 3,
#  'VTC+Mobile+Southern': 3,
#  'VTC+Online,.JSC': 3,
#  '1600022992': 20,
#  'VNG+ZingPlay+Game+Studios': 20,
#  'VNG+ZingPlay+Studio': 20,
#  'ZINGPLAY+VIETNAM': 20}

# %%
len(dict_publisher_id_revenue_multiplier)
# Out:
# 136
